# %% [markdown]
# # Ahmedabad Housing Analysis
# ###       By Maharshi Pandya

# %% [markdown]
# The First step is to import all the necessary libraries into our notebook

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np 
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
conda install -c conda-forge folium --yes 
import folium
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# In this step, we are going to scrap data for our project and assign it to variable named d1

# %%
# !wget -q -O 'sample.html' https://www.makaan.com/price-trends/property-rates-for-buy-in-ahmedabad
print('Data downloaded!')
with open('sample.html') as Sampledata:
    soup = BeautifulSoup(Sampledata , 'lxml')
d1 = soup.find('div' , class_ = 'locality-trends max980')
# Out:
# Data downloaded!

# %% [markdown]
# Here, We are going to isolate data and going to create 4 indepedant list of our data.

# %%
data=[]
locality =[]
price_range =[]
avg_price=[]
rise_price =[]
for row in d1.find_all('tr'):
    for cell in row.find_all('td'):
        data.append(cell.text)
    if(len(data)>5):
        locality.append(data[0])
        price_range.append(data[1])
        avg_price.append(data[2])
        rise_price.append(data[3].rstrip('\n'))
    data=[]

# %% [markdown]
# In this step, we are making a data frame of a data from above

# %%
amdavad = pd.DataFrame({"Borough" : locality , "Price Range" : price_range , "Average Price":avg_price, "Rise Price" : rise_price})
amdavad['Price Range'].replace('-',np.nan,inplace=True)
amdavad['Average Price'].replace('-',np.nan,inplace=True)
amdavad.head()
# Out:
#          Borough             Price Range      Average Price Rise Price
# 0          Bopal     393 - 64,516 / sqft   12,367.37 / sqft      24.5%
# 1  Prahlad Nagar   2,381 - 14,842 / sqft   11,189.54 / sqft      20.9%
# 2      Satellite   1,895 - 44,922 / sqft   30,112.94 / sqft      56.9%
# 3          Shela    2,400 - 6,790 / sqft     6,32.26 / sqft      22.3%
# 4           Gota   2,346 - 14,706 / sqft    9,472.09 / sqft       9.3%

# %% [markdown]
# In this step, we are sorting data according to their average proce from lowest to highest

# %%
sorted_city= amdavad.sort_values(by=['Average Price'])
sorted_city.head()
# Out:
#                           Borough            Price Range     Average Price  \
# 155                         Nikol     600 - 1,200 / sqft      1,200 / sqft
# 19                        Dholera   1,610 - 1,673 / sqft   1,642.77 / sqft
# 227                         Vatva           1,667 / sqft   1,666.67 / sqft
# 228                        Naroda           1,778 / sqft    1,778.5 / sqft
# 206  Ahmedabad Patan Highway Road           1,939 / sqft   1,939.39 / sqft
#
#     Rise Price
# 155       486%
# 19           -
# 227          -
# 228          -
# 206          -

# %% [markdown]
# Here ,we are finding the average location of ahmedabad city.

# %%
address = ' Ahemedabad'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Ahmedabad are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Ahmedabad are 23.0496453, 72.6071588.

# %% [markdown]
# ### This is hidden cell, here I uploaded data of lat and lon of city to watson studio project assets and then called it here.

# %% [markdown]
# Now in this step, I am just sorting the table

# %%
final_table = sorted_city.set_index('Borough').join(geo_data.set_index('Name'))
final_table = final_table.reset_index(drop=False)
final_table
# Out:
#                                                  index  \
# 0                         Adani Group Adani Shantigram
# 1                              Adani Group The Meadows
# 2                               Adani Group Water Lily
# 3                                    Adi Heritage Skyz
# 4                         Ahmedabad Patan Highway Road
# 5                         Ahmedabad Patan Highway Road
# 6                         Ahmedabad Patan Highway Road
# 7                         Ahmedabad Patan Highway Road
# 8    Ajmera Group And Sheetal Infrastructure Pvt Lt...
# 9                                             Ambavadi
# 10                                            Ambavadi
# 11                                            Ambavadi
# 12                                            Ambavadi
# 13                                               Ambli
# 14                                               Ambli
# 15                                               Ambli
# 16                                               Ambli
# 17                            Applewoods Estate Sorrel
# 18                                              Bholad
# 19                                              Bholad
# 20                                              Bholad
# 21                                              Bholad
# 22                                            Bodakdev
# 23                                            Bodakdev
# 24                                            Bodakdev
# 25                                            Bodakdev
# 26                                               Bopal
# 27                                               Bopal
# 28                                               Bopal
# 29                                               Bopal
# ..                                                 ...
# 230                                            Thaltej
# 231                                Thaltej Shilaj Road
# 232                                Thaltej Shilaj Road
# 233                                Thaltej Shilaj Road
# 234                                Thaltej Shilaj Road
# 235                               Unity Domain Heights
# 236                                        Vaishnodevi
# 237                                        Vaishnodevi
# 238                                        Vaishnodevi
# 239                                        Vaishnodevi
# 240                                              Vasna
# 241                                              Vasna
# 242                                              Vasna
# 243                                              Vasna
# 244                                            Vastral
# 245                                            Vastral
# 246                                            Vastral
# 247                                            Vastral
# 248                                          Vastrapur
# 249                                          Vastrapur
# 250                                          Vastrapur
# 251                                          Vastrapur
# 252                                              Vatva
# 253                                              Vatva
# 254                                              Vatva
# 255                                              Vatva
# 256                                           Vejalpur
# 257                                           Vejalpur
# 258                                           Vejalpur
# 259                                           Vejalpur
#
#                  Price Range      Average Price Rise Price   Latitude  \
# 0      2,507 - 14,258 / sqft              4,785         8%        NaN
# 1       3,111 - 8,112 / sqft              4,485      22.1%        NaN
# 2       3,150 - 9,126 / sqft              3,790      25.6%        NaN
# 3       5,714 - 6,904 / sqft              6,308          -        NaN
# 4               1,939 / sqft    1,939.39 / sqft          -        NaN
# 5         253 - 3,898 / sqft    3,897.73 / sqft          -        NaN
# 6      1,017 - 12,831 / sqft    8,105.72 / sqft          -        NaN
# 7                        NaN                NaN          -        NaN
# 8       4,932 - 7,420 / sqft              6,084      -8.5%        NaN
# 9      8,333 - 23,641 / sqft   23,640.66 / sqft     -42.7%        NaN
# 10              5,437 / sqft    5,437.35 / sqft          -        NaN
# 11              9,437 / sqft    9,437.17 / sqft      44.4%        NaN
# 12     3,214 - 13,000 / sqft    9,844.74 / sqft          -        NaN
# 13     3,600 - 18,548 / sqft   13,320.91 / sqft      -5.1%        NaN
# 14    16,022 - 17,568 / sqft   17,567.57 / sqft     103.7%        NaN
# 15    12,500 - 22,449 / sqft   22,448.98 / sqft     212.8%        NaN
# 16                       NaN                NaN          -        NaN
# 17      3,268 - 4,402 / sqft              3,673     -17.2%        NaN
# 18          276 - 398 / sqft      398.31 / sqft          -        NaN
# 19                       NaN                NaN       7.9%        NaN
# 20                       NaN                NaN          -        NaN
# 21                       NaN                NaN          -        NaN
# 22             10,770 / sqft   10,770.21 / sqft          -        NaN
# 23       577 - 22,500 / sqft   10,966.68 / sqft          -        NaN
# 24     6,000 - 25,000 / sqft    18,472.2 / sqft     460.4%        NaN
# 25     2,800 - 24,074 / sqft    24,74.07 / sqft     -55.3%        NaN
# 26     3,289 - 13,636 / sqft   11,635.27 / sqft        49%        NaN
# 27       393 - 64,516 / sqft   12,367.37 / sqft      24.5%        NaN
# 28       155 - 40,076 / sqft   36,749.52 / sqft      30.5%        NaN
# 29                       NaN                NaN          -        NaN
# ..                       ...                ...        ...        ...
# 230             3,564 / sqft    3,563.94 / sqft          -  23.050203
# 231    9,615 - 16,908 / sqft   14,714.98 / sqft          -        NaN
# 232            16,667 / sqft   16,666.67 / sqft          -        NaN
# 233     3,569 - 7,200 / sqft    6,308.91 / sqft          -        NaN
# 234                      NaN                NaN          -        NaN
# 235     5,998 - 6,155 / sqft              6,124      -7.9%        NaN
# 236     1,778 - 2,500 / sqft       2,500 / sqft          -        NaN
# 237    2,796 - 40,263 / sqft   22,998.92 / sqft     -11.6%        NaN
# 238    4,360 - 51,639 / sqft   29,332.96 / sqft     -11.5%        NaN
# 239             3,592 / sqft    3,592.27 / sqft          -        NaN
# 240             3,423 / sqft    3,422.67 / sqft          -  23.000582
# 241             4,074 / sqft     4,74.07 / sqft          -  23.000582
# 242    3,062 - 18,000 / sqft    9,965.49 / sqft       -30%  23.000582
# 243                      NaN                NaN      -6.4%  23.000582
# 244     1,416 - 4,416 / sqft    3,720.28 / sqft      24.1%  23.000208
# 245     2,670 - 8,889 / sqft       5,990 / sqft          -  23.000208
# 246     4,293 - 8,035 / sqft     7,61.72 / sqft     -51.4%  23.000208
# 247                      NaN                NaN          -  23.000208
# 248            18,519 / sqft   18,518.52 / sqft     -61.4%        NaN
# 249     4,324 - 7,500 / sqft    6,570.37 / sqft          -        NaN
# 250    1,975 - 15,000 / sqft    9,680.84 / sqft      39.9%        NaN
# 251    3,583 - 11,605 / sqft    9,819.41 / sqft      82.8%        NaN
# 252             1,667 / sqft    1,666.67 / sqft          -  22.952902
# 253     2,738 - 3,095 / sqft    2,797.56 / sqft       5.6%  22.952902
# 254     1,528 - 4,973 / sqft    4,269.27 / sqft      33.7%  22.952902
# 255               793 / sqft         793 / sqft     250.3%  22.952902
# 256     3,457 - 7,819 / sqft    5,637.86 / sqft      40.8%  23.003962
# 257             5,727 / sqft    5,726.87 / sqft          -  23.003962
# 258     1,893 - 7,485 / sqft    5,901.81 / sqft       9.3%  23.003962
# 259                      NaN                NaN          -  23.003962
#
#      Longitude
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ..         ...
# 230  72.512842
# 231        NaN
# 232        NaN
# 233        NaN
# 234        NaN
# 235        NaN
# 236        NaN
# 237        NaN
# 238        NaN
# 239        NaN
# 240  72.550185
# 241  72.550185
# 242  72.550185
# 243  72.550185
# 244  72.646211
# 245  72.646211
# 246  72.646211
# 247  72.646211
# 248        NaN
# 249        NaN
# 250        NaN
# 251        NaN
# 252  72.617033
# 253  72.617033
# 254  72.617033
# 255  72.617033
# 256  72.523262
# 257  72.523262
# 258  72.523262
# 259  72.523262
#
# [260 rows x 6 columns]

# %%
final_table.dropna(axis=0, how='all', inplace=False)
final_table.Latitude.unique()
avg_lat=final_table['Latitude'].astype('float').mean(axis=0)
final_table['Latitude'].replace(np.nan, avg_lat, inplace=True)
avg_lon=final_table['Longitude'].astype('float').mean(axis=0)
final_table['Longitude'].replace(np.nan, avg_lon, inplace=True)

# %%
map_amdavad = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, AveragePrice in zip(final_table['Latitude'], final_table['Longitude'], final_table['index'],final_table['Average Price']):
    label = '{} , {}'.format(borough , AveragePrice)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_amdavad)  
map_amdavad
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
